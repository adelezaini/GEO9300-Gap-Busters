# %% [markdown]
# ## Numerical method to evaluate Ts, and all the other output variables

# %%
import numpy as np
import matplotlib.pyplot as plt
from equations import *
import pandas as pd

# %%
path = '../data/synthetic_dataset/'
file_list = ['SWin','SWout', 'LWin', 'Tair', 'RH_air', 'wind_speed', 'total_precipitation', 'snow_cover_fraction', 'surface_pressure']
variable_list = ['SWin','SWout', 'LWin', 'Tair', 'RH_air', 'u', 'prec', 'snow_cover', 'pressure']

for i, variable_name in enumerate(file_list):
    if i == 0: input_data = pd.read_csv(path + variable_name + '.csv', index_col="time", parse_dates=True)
    else: input_data[variable_list[i]] = pd.read_csv(path + variable_name + '.csv', index_col="time", parse_dates=True)[variable_list[i]]

#data

# %% [markdown]
# ### Without constraint on Ts

# %%
# Function to solve for Ts at each time step
def solve_Ts(SWin, SWout, LWin, Tair, RH_air, u, prec, snow_cover):
    
    # Define the equation to solve
    def equation_system(Ts):
        
        LWout = longwave_out(Ts)
        SH = sensible_heat_flux(u, Ts, Tair)
        RH_s = surface_relative_humidity(RH_air, Ts, Tair, prec, snow_cover, u)
        q_s = specific_humidity(Ts, RH_s)
        q_air = specific_humidity(Tair, RH_air)
        LE = latent_heat_flux(u, q_s, q_air)
        #energy = energy_balance(SWin, SWout, LWin, LWout, SH, LE)
        #print(f"Energy balance for Ts={Ts}: {energy}")

        return energy_balance(SWin, SWout, LWin, LWout, SH, LE)

    # Define constraints
    #def constraint(Ts):
        # Limit Ts to be within a certain range of Tair
        # For example, Ts should not be more than 20°C higher or lower than Tair
        #return min(max(Tair - 20, Ts), Tair + 20) - Ts

    """
    def T_constraint(Ts):
        # Avoid Ts, when evaluated numerically, to be too far off compared to the Tair
        if snow_cover > 0.5:  # High snow cover: limit Ts deviation
          return max(min(Ts, Tair + 2), Tair - 2)  # Allow a 2 K deviation from Tair
        elif prec > 0:  # During precipitation: keep Ts closer to Tair
          return max(min(Ts, Tair + 5), Tair - 5)  # Allow a 5 K deviation from Tair
        else:  # No snow/precip: allow more variability
          return max(min(Ts, Tair + 10), Tair - 10)  # Allow up to 10 K deviation"""

    # Initial guess for Ts (e.g., ambient air temperature)
    initial_guess = Tair

    # Solve the equation with constraints
    #solution = root(lambda x: [equation_system(x[0]), constraint(x[0])], [initial_guess])
    solution = root(equation_system, initial_guess)
    
    # Check if the solution converged
    if solution.success:
        return solution.x[0]
    else:
        raise ValueError("Solution did not converge")

# %%
def calculate_surface_temperatures(df):
    """
    Calculate surface temperatures using the time series data from a DataFrame.

    Parameters:
        df (DataFrame): DataFrame with columns: 'SWin', 'SWout', 'LWin', 'Tair', 'u', 'q_air', 'RHs'

    Returns:
        np.array: Array of calculated surface temperatures (Ts) for each row in the DataFrame.
    """
    Ts_values = []
    for _, row in df.iterrows():
        Ts = solve_Ts(
            SWin=row['SWin'], 
            SWout=row['SWout'], 
            LWin=row['LWin'], 
            Tair=row['Tair'], 
            u=row['u'], 
            RH_air=row['RH_air'], 
            prec =row['prec'], 
            snow_cover =row['snow_cover']
        )
        Ts_values.append(Ts)
    return pd.DataFrame({'Ts': Ts_values}, index=df.index)#np.array(Ts_values)

# Example: Calculate Ts for each time step
Ts_values = calculate_surface_temperatures(input_data)

# %%
Ts_values.plot()

input_data['Tair'].plot(label = 'Tair')
plt.legend()

# %% [markdown]
# ### With constraint on Ts (+/- 15 °C from Tair)

# %%
from scipy.optimize import minimize

def solve_Ts(SWin, SWout, LWin, Tair, RH_air, u, prec, snow_cover, pressure = 894.1191):
    # Define the equation to minimize (energy balance should approach 0)
    def equation_system(Ts):
        LWout = longwave_out(Ts[0])
        SH = sensible_heat_flux(u, Ts[0], Tair)
        RH_s = surface_relative_humidity(RH_air, Ts[0], Tair, prec, snow_cover, u)
        q_s = specific_humidity(Ts[0], RH_s, pressure)
        q_air = specific_humidity(Tair, RH_air, pressure)
        LE = latent_heat_flux(u, q_s, q_air)
        return energy_balance(SWin, SWout, LWin, LWout, SH, LE)**2  # Squared for minimization

    # Bounds for Ts: within ±20°C of Tair
    T_constrain = 15
    Ts_bounds = [(Tair - T_constrain, Tair + T_constrain)]

    # Initial guess for Ts
    initial_guess = [Tair]

    # Minimize the energy balance function
    result = minimize(equation_system, initial_guess, bounds=Ts_bounds, method='L-BFGS-B')

    # Check if the solution converged
    if result.success:
        return result.x[0]
    else:
        raise ValueError("Solution did not converge")

# %%
def calculate_surface_temperatures(df, verbose=True):
    Ts_values = []
    non_converge_count = 0  # Initialize the counter for non-convergences
    
    for idx, row in df.iterrows():
        try:
            Ts = solve_Ts(
                SWin=row['SWin'], 
                SWout=row['SWout'], 
                LWin=row['LWin'], 
                Tair=row['Tair'], 
                u=row['u'], 
                RH_air=row['RH_air'], 
                prec=row['prec'], 
                snow_cover=row['snow_cover'],
                pressure=row['pressure']
            )
            Ts_values.append(Ts)
        except ValueError as e:
            non_converge_count += 1  # Increment the counter
            if verbose:
                print(f"{e} at index {idx}: assigning to Ts the previous hour value ({round(Ts_values[-1], 2)})")
            Ts_values.append(Ts_values[-1])  # Assign the previous value
    
    print(f"1nNumerical method of Ts - solution did not converge {non_converge_count} times. \nTs values filled with the respectively previous value in the time series.")
    
    return pd.DataFrame({'Ts': Ts_values}, index=df.index)

# Example usage
Ts_values = calculate_surface_temperatures(input_data)
# Out:
# Solution did not converge at index 2019-02-01 17:00:00: assigning to Ts the previous hour value (262.76)
# Solution did not converge at index 2019-03-17 04:00:00: assigning to Ts the previous hour value (267.0)
# Solution did not converge at index 2019-04-04 10:00:00: assigning to Ts the previous hour value (274.83)
# Solution did not converge at index 2019-04-23 10:00:00: assigning to Ts the previous hour value (282.62)
# Solution did not converge at index 2019-04-23 11:00:00: assigning to Ts the previous hour value (282.62)
# Solution did not converge at index 2019-04-23 13:00:00: assigning to Ts the previous hour value (286.25)
# Solution did not converge at index 2019-04-23 14:00:00: assigning to Ts the previous hour value (286.25)
# Solution did not converge at index 2019-04-24 06:00:00: assigning to Ts the previous hour value (272.88)
# Solution did not converge at index 2019-04-30 22:00:00: assigning to Ts the previous hour value (280.82)
# Solution did not converge at index 2019-04-30 23:00:00: assigning to Ts the previous hour value (280.82)
# Solution did not converge at index 2019-05-01 01:00:00: assigning to Ts the previous hour value (280.65)
# Solution did not converge at index 2019-05-01 02:00:00: assigning to Ts the previous hour value (280.65)
# Solution did not converge at index 2019-05-01 09:00:00: assigning to Ts the previous hour value (286.39)
# Solution did not converge at index 2019-05-01 16:00:00: assigning to Ts the previous hour value (284.01)
# Solution did not converge at index 2019-05-01 23:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 00:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 01:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 02:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 03:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 04:00:00: assigning to Ts the previous hour value (274.47)
# Solution did not converge at index 2019-05-02 20:00:00: assigning to Ts the previous hour value (272.45)
# Solution did not converge at index 2019-05-02 21:00:00: assigning to Ts the previous hour value (272.45)
# Solution did not converge at index 2019-05-02 22:00:00: assigning to Ts the previous hour value (272.45)
# Solution did not converge at index 2019-05-02 23:00:00: assigning to Ts the previous hour value (272.45)
# Solution did not converge at index 2019-05-03 03:00:00: assigning to Ts the previous hour value (266.75)
# Solution did not converge at index 2019-05-03 07:00:00: assigning to Ts the previous hour value (269.93)
# Solution did not converge at index 2019-05-03 22:00:00: assigning to Ts the previous hour value (267.85)
# Solution did not converge at index 2019-05-03 23:00:00: assigning to Ts the previous hour value (267.85)
# Solution did not converge at index 2019-05-04 17:00:00: assigning to Ts the previous hour value (277.23)
# Solution did not converge at index 2019-05-05 07:00:00: assigning to Ts the previous hour value (272.29)
# Solution did not converge at index 2019-05-05 22:00:00: assigning to Ts the previous hour value (271.28)
# Solution did not converge at index 2019-05-06 00:00:00: assigning to Ts the previous hour value (270.74)
# Solution did not converge at index 2019-05-06 01:00:00: assigning to Ts the previous hour value (270.74)
# Solution did not converge at index 2019-05-06 07:00:00: assigning to Ts the previous hour value (271.18)
# Solution did not converge at index 2019-05-06 18:00:00: assigning to Ts the previous hour value (274.0)
# Solution did not converge at index 2019-05-07 01:00:00: assigning to Ts the previous hour value (268.18)
# Solution did not converge at index 2019-05-07 03:00:00: assigning to Ts the previous hour value (266.51)
# Solution did not converge at index 2019-05-07 04:00:00: assigning to Ts the previous hour value (266.51)
# Solution did not converge at index 2019-05-07 05:00:00: assigning to Ts the previous hour value (266.51)
# Solution did not converge at index 2019-05-07 06:00:00: assigning to Ts the previous hour value (266.51)
# Solution did not converge at index 2019-05-07 17:00:00: assigning to Ts the previous hour value (278.58)
# Solution did not converge at index 2019-05-11 02:00:00: assigning to Ts the previous hour value (272.62)
# Solution did not converge at index 2019-05-11 03:00:00: assigning to Ts the previous hour value (272.62)
# Solution did not converge at index 2019-05-11 11:00:00: assigning to Ts the previous hour value (283.03)
# Solution did not converge at index 2019-05-11 12:00:00: assigning to Ts the previous hour value (283.03)
# Solution did not converge at index 2019-05-12 06:00:00: assigning to Ts the previous hour value (271.35)
# Solution did not converge at index 2019-05-13 02:00:00: assigning to Ts the previous hour value (268.16)
# Solution did not converge at index 2019-05-13 06:00:00: assigning to Ts the previous hour value (271.22)
# Solution did not converge at index 2019-05-25 01:00:00: assigning to Ts the previous hour value (276.67)
# Solution did not converge at index 2019-05-25 06:00:00: assigning to Ts the previous hour value (278.61)
# Solution did not converge at index 2019-05-26 02:00:00: assigning to Ts the previous hour value (274.51)
# Solution did not converge at index 2019-05-26 03:00:00: assigning to Ts the previous hour value (274.51)
# Solution did not converge at index 2019-05-28 02:00:00: assigning to Ts the previous hour value (272.93)
# Solution did not converge at index 2019-05-29 00:00:00: assigning to Ts the previous hour value (270.82)
# Solution did not converge at index 2019-05-29 14:00:00: assigning to Ts the previous hour value (286.65)
# Solution did not converge at index 2019-05-30 16:00:00: assigning to Ts the previous hour value (284.45)
# Solution did not converge at index 2019-05-30 18:00:00: assigning to Ts the previous hour value (281.41)
# Solution did not converge at index 2019-05-30 23:00:00: assigning to Ts the previous hour value (271.55)
# Solution did not converge at index 2019-05-31 00:00:00: assigning to Ts the previous hour value (271.55)
# Solution did not converge at index 2019-05-31 02:00:00: assigning to Ts the previous hour value (272.47)
# Solution did not converge at index 2019-05-31 09:00:00: assigning to Ts the previous hour value (282.54)
# Solution did not converge at index 2019-06-02 02:00:00: assigning to Ts the previous hour value (276.31)
# Solution did not converge at index 2019-06-04 07:00:00: assigning to Ts the previous hour value (282.36)
# Solution did not converge at index 2019-06-11 15:00:00: assigning to Ts the previous hour value (297.27)
# Solution did not converge at index 2019-06-12 13:00:00: assigning to Ts the previous hour value (280.56)
# Solution did not converge at index 2019-06-12 14:00:00: assigning to Ts the previous hour value (280.56)
# Solution did not converge at index 2019-06-17 14:00:00: assigning to Ts the previous hour value (294.04)
# Solution did not converge at index 2019-06-18 15:00:00: assigning to Ts the previous hour value (284.76)
# Solution did not converge at index 2019-06-21 18:00:00: assigning to Ts the previous hour value (287.85)
# Solution did not converge at index 2019-06-21 22:00:00: assigning to Ts the previous hour value (277.37)
# Solution did not converge at index 2019-06-21 23:00:00: assigning to Ts the previous hour value (277.37)
# Solution did not converge at index 2019-06-22 00:00:00: assigning to Ts the previous hour value (277.37)
# Solution did not converge at index 2019-06-22 01:00:00: assigning to Ts the previous hour value (277.37)
# Solution did not converge at index 2019-06-22 02:00:00: assigning to Ts the previous hour value (277.37)
# Solution did not converge at index 2019-06-22 06:00:00: assigning to Ts the previous hour value (279.22)
# Solution did not converge at index 2019-06-26 21:00:00: assigning to Ts the previous hour value (284.5)
# Solution did not converge at index 2019-06-27 00:00:00: assigning to Ts the previous hour value (280.59)
# Solution did not converge at index 2019-06-27 02:00:00: assigning to Ts the previous hour value (279.32)
# Solution did not converge at index 2019-06-27 03:00:00: assigning to Ts the previous hour value (279.32)
# Solution did not converge at index 2019-06-28 04:00:00: assigning to Ts the previous hour value (278.71)
# Solution did not converge at index 2019-06-29 01:00:00: assigning to Ts the previous hour value (286.6)
# Solution did not converge at index 2019-06-29 09:00:00: assigning to Ts the previous hour value (291.34)
# Solution did not converge at index 2019-06-30 15:00:00: assigning to Ts the previous hour value (294.49)
# Solution did not converge at index 2019-06-30 18:00:00: assigning to Ts the previous hour value (290.94)
# Solution did not converge at index 2019-06-30 21:00:00: assigning to Ts the previous hour value (283.45)
# Solution did not converge at index 2019-07-01 06:00:00: assigning to Ts the previous hour value (284.38)
# Solution did not converge at index 2019-07-01 11:00:00: assigning to Ts the previous hour value (283.96)
# Solution did not converge at index 2019-07-01 14:00:00: assigning to Ts the previous hour value (291.41)
# Solution did not converge at index 2019-07-01 15:00:00: assigning to Ts the previous hour value (291.41)
# Solution did not converge at index 2019-07-01 18:00:00: assigning to Ts the previous hour value (289.31)
# Solution did not converge at index 2019-07-01 22:00:00: assigning to Ts the previous hour value (282.06)
# Solution did not converge at index 2019-07-01 23:00:00: assigning to Ts the previous hour value (282.06)
# Solution did not converge at index 2019-07-02 00:00:00: assigning to Ts the previous hour value (282.06)
# Solution did not converge at index 2019-07-02 01:00:00: assigning to Ts the previous hour value (282.06)
# Solution did not converge at index 2019-07-02 06:00:00: assigning to Ts the previous hour value (277.68)
# Solution did not converge at index 2019-07-03 00:00:00: assigning to Ts the previous hour value (276.11)
# Solution did not converge at index 2019-07-03 20:00:00: assigning to Ts the previous hour value (279.77)
# Solution did not converge at index 2019-07-04 08:00:00: assigning to Ts the previous hour value (283.33)
# Solution did not converge at index 2019-07-04 18:00:00: assigning to Ts the previous hour value (285.92)
# Solution did not converge at index 2019-07-05 03:00:00: assigning to Ts the previous hour value (274.3)
# Solution did not converge at index 2019-07-05 06:00:00: assigning to Ts the previous hour value (278.44)
# Solution did not converge at index 2019-07-05 18:00:00: assigning to Ts the previous hour value (292.19)
# Solution did not converge at index 2019-07-05 23:00:00: assigning to Ts the previous hour value (282.01)
# Solution did not converge at index 2019-07-06 08:00:00: assigning to Ts the previous hour value (283.74)
# Solution did not converge at index 2019-07-10 18:00:00: assigning to Ts the previous hour value (294.06)
# Solution did not converge at index 2019-07-11 18:00:00: assigning to Ts the previous hour value (295.4)
# Solution did not converge at index 2019-07-13 22:00:00: assigning to Ts the previous hour value (284.63)
# Solution did not converge at index 2019-07-14 22:00:00: assigning to Ts the previous hour value (285.09)
# Solution did not converge at index 2019-07-14 23:00:00: assigning to Ts the previous hour value (285.09)
# Solution did not converge at index 2019-07-15 00:00:00: assigning to Ts the previous hour value (285.09)
# Solution did not converge at index 2019-07-15 06:00:00: assigning to Ts the previous hour value (284.77)
# Solution did not converge at index 2019-07-15 21:00:00: assigning to Ts the previous hour value (285.45)
# Solution did not converge at index 2019-07-15 22:00:00: assigning to Ts the previous hour value (285.45)
# Solution did not converge at index 2019-07-15 23:00:00: assigning to Ts the previous hour value (285.45)
# Solution did not converge at index 2019-07-16 00:00:00: assigning to Ts the previous hour value (285.45)
# Solution did not converge at index 2019-08-03 22:00:00: assigning to Ts the previous hour value (284.29)
# Solution did not converge at index 2019-08-13 09:00:00: assigning to Ts the previous hour value (284.73)
# Solution did not converge at index 2019-08-13 15:00:00: assigning to Ts the previous hour value (291.4)
# Solution did not converge at index 2019-08-13 21:00:00: assigning to Ts the previous hour value (280.37)
# Solution did not converge at index 2019-08-13 23:00:00: assigning to Ts the previous hour value (278.81)
# Solution did not converge at index 2019-08-14 04:00:00: assigning to Ts the previous hour value (277.72)
# Solution did not converge at index 2019-08-21 03:00:00: assigning to Ts the previous hour value (277.55)
# Solution did not converge at index 2019-08-23 09:00:00: assigning to Ts the previous hour value (289.06)
# Solution did not converge at index 2019-08-23 14:00:00: assigning to Ts the previous hour value (294.29)
# Solution did not converge at index 2019-08-31 17:00:00: assigning to Ts the previous hour value (286.91)
# Solution did not converge at index 2019-09-02 13:00:00: assigning to Ts the previous hour value (290.84)
# Solution did not converge at index 2019-09-03 14:00:00: assigning to Ts the previous hour value (292.33)
# Solution did not converge at index 2019-09-03 16:00:00: assigning to Ts the previous hour value (290.19)
# Solution did not converge at index 2019-09-05 02:00:00: assigning to Ts the previous hour value (277.4)
# Solution did not converge at index 2019-09-05 03:00:00: assigning to Ts the previous hour value (277.4)
# Solution did not converge at index 2019-09-05 16:00:00: assigning to Ts the previous hour value (285.5)
# Solution did not converge at index 2019-09-07 08:00:00: assigning to Ts the previous hour value (280.37)
# Solution did not converge at index 2019-09-07 09:00:00: assigning to Ts the previous hour value (280.37)
# Solution did not converge at index 2019-09-08 09:00:00: assigning to Ts the previous hour value (281.27)
# Solution did not converge at index 2019-09-11 21:00:00: assigning to Ts the previous hour value (278.42)
# Solution did not converge at index 2019-09-11 22:00:00: assigning to Ts the previous hour value (278.42)
# Solution did not converge at index 2019-09-11 23:00:00: assigning to Ts the previous hour value (278.42)
# Solution did not converge at index 2019-09-12 00:00:00: assigning to Ts the previous hour value (278.42)
# Solution did not converge at index 2019-09-12 08:00:00: assigning to Ts the previous hour value (280.91)
# Solution did not converge at index 2019-09-12 09:00:00: assigning to Ts the previous hour value (280.91)
# Solution did not converge at index 2019-09-12 12:00:00: assigning to Ts the previous hour value (286.97)
# Solution did not converge at index 2019-09-12 22:00:00: assigning to Ts the previous hour value (276.51)
# Solution did not converge at index 2019-09-12 23:00:00: assigning to Ts the previous hour value (276.51)
# Solution did not converge at index 2019-09-13 01:00:00: assigning to Ts the previous hour value (276.43)
# Solution did not converge at index 2019-09-13 02:00:00: assigning to Ts the previous hour value (276.43)
# Solution did not converge at index 2019-09-13 03:00:00: assigning to Ts the previous hour value (276.43)
# Solution did not converge at index 2019-09-13 04:00:00: assigning to Ts the previous hour value (276.43)
# Solution did not converge at index 2019-09-13 05:00:00: assigning to Ts the previous hour value (276.43)
# Solution did not converge at index 2019-09-13 16:00:00: assigning to Ts the previous hour value (284.3)
# Solution did not converge at index 2019-09-13 18:00:00: assigning to Ts the previous hour value (280.42)
# Solution did not converge at index 2019-09-13 22:00:00: assigning to Ts the previous hour value (275.97)
# Solution did not converge at index 2019-09-13 23:00:00: assigning to Ts the previous hour value (275.97)
# Solution did not converge at index 2019-09-14 01:00:00: assigning to Ts the previous hour value (275.31)
# Solution did not converge at index 2019-09-15 05:00:00: assigning to Ts the previous hour value (275.65)
# Solution did not converge at index 2019-09-15 09:00:00: assigning to Ts the previous hour value (278.23)
# Solution did not converge at index 2019-09-15 14:00:00: assigning to Ts the previous hour value (282.78)
# Solution did not converge at index 2019-09-16 03:00:00: assigning to Ts the previous hour value (274.58)
# Solution did not converge at index 2019-09-16 04:00:00: assigning to Ts the previous hour value (274.58)
# Solution did not converge at index 2019-09-17 08:00:00: assigning to Ts the previous hour value (274.43)
# Solution did not converge at index 2019-09-17 20:00:00: assigning to Ts the previous hour value (274.6)
# Solution did not converge at index 2019-09-17 23:00:00: assigning to Ts the previous hour value (274.53)
# Solution did not converge at index 2019-09-18 00:00:00: assigning to Ts the previous hour value (274.53)
# Solution did not converge at index 2019-09-18 03:00:00: assigning to Ts the previous hour value (274.81)
# Solution did not converge at index 2019-09-18 05:00:00: assigning to Ts the previous hour value (274.32)
# Solution did not converge at index 2019-09-18 19:00:00: assigning to Ts the previous hour value (275.7)
# Solution did not converge at index 2019-09-18 20:00:00: assigning to Ts the previous hour value (275.7)
# Solution did not converge at index 2019-09-18 22:00:00: assigning to Ts the previous hour value (273.95)
# Solution did not converge at index 2019-09-18 23:00:00: assigning to Ts the previous hour value (273.95)
# Solution did not converge at index 2019-09-19 00:00:00: assigning to Ts the previous hour value (273.95)
# Solution did not converge at index 2019-09-19 01:00:00: assigning to Ts the previous hour value (273.95)
# Solution did not converge at index 2019-09-19 02:00:00: assigning to Ts the previous hour value (273.95)
# Solution did not converge at index 2019-09-20 12:00:00: assigning to Ts the previous hour value (291.54)
# Solution did not converge at index 2019-09-21 03:00:00: assigning to Ts the previous hour value (285.81)
# Solution did not converge at index 2019-09-22 13:00:00: assigning to Ts the previous hour value (295.68)
# Solution did not converge at index 2019-09-30 05:00:00: assigning to Ts the previous hour value (276.92)
# Solution did not converge at index 2019-09-30 06:00:00: assigning to Ts the previous hour value (276.92)
# Solution did not converge at index 2019-09-30 09:00:00: assigning to Ts the previous hour value (278.43)
# Solution did not converge at index 2019-09-30 15:00:00: assigning to Ts the previous hour value (278.77)
# Solution did not converge at index 2019-09-30 18:00:00: assigning to Ts the previous hour value (273.06)
# Solution did not converge at index 2019-09-30 19:00:00: assigning to Ts the previous hour value (273.06)
# Solution did not converge at index 2019-10-01 06:00:00: assigning to Ts the previous hour value (273.25)
# Solution did not converge at index 2019-10-01 15:00:00: assigning to Ts the previous hour value (279.86)
# Solution did not converge at index 2019-10-01 18:00:00: assigning to Ts the previous hour value (274.57)
# Solution did not converge at index 2019-10-01 19:00:00: assigning to Ts the previous hour value (274.57)
# Solution did not converge at index 2019-10-01 21:00:00: assigning to Ts the previous hour value (273.51)
# Solution did not converge at index 2019-10-13 00:00:00: assigning to Ts the previous hour value (272.95)
# Solution did not converge at index 2019-10-14 07:00:00: assigning to Ts the previous hour value (273.12)
# Solution did not converge at index 2019-10-23 11:00:00: assigning to Ts the previous hour value (280.45)
# Solution did not converge at index 2019-10-23 12:00:00: assigning to Ts the previous hour value (280.45)
# Solution did not converge at index 2019-10-25 07:00:00: assigning to Ts the previous hour value (274.57)
# Solution did not converge at index 2019-10-25 11:00:00: assigning to Ts the previous hour value (275.68)
# Solution did not converge at index 2019-10-25 12:00:00: assigning to Ts the previous hour value (275.68)
# Solution did not converge at index 2019-10-27 20:00:00: assigning to Ts the previous hour value (269.2)
# Solution did not converge at index 2019-10-27 21:00:00: assigning to Ts the previous hour value (269.2)
# Solution did not converge at index 2019-10-27 22:00:00: assigning to Ts the previous hour value (269.2)
# Solution did not converge at index 2019-10-27 23:00:00: assigning to Ts the previous hour value (269.2)
# Solution did not converge at index 2019-10-28 08:00:00: assigning to Ts the previous hour value (269.31)
# Solution did not converge at index 2019-10-29 01:00:00: assigning to Ts the previous hour value (267.62)
# Solution did not converge at index 2019-10-29 03:00:00: assigning to Ts the previous hour value (267.67)
# Solution did not converge at index 2019-10-29 04:00:00: assigning to Ts the previous hour value (267.67)
# Solution did not converge at index 2019-10-30 14:00:00: assigning to Ts the previous hour value (275.91)
# Solution did not converge at index 2019-10-31 03:00:00: assigning to Ts the previous hour value (272.45)
# Solution did not converge at index 2019-10-31 12:00:00: assigning to Ts the previous hour value (276.19)
# Solution did not converge at index 2019-11-02 16:00:00: assigning to Ts the previous hour value (269.22)
# Solution did not converge at index 2019-11-02 19:00:00: assigning to Ts the previous hour value (267.76)
# Solution did not converge at index 2019-11-02 20:00:00: assigning to Ts the previous hour value (267.76)
# Solution did not converge at index 2019-11-02 21:00:00: assigning to Ts the previous hour value (267.76)
# Solution did not converge at index 2019-11-03 07:00:00: assigning to Ts the previous hour value (268.82)
# Solution did not converge at index 2019-11-04 12:00:00: assigning to Ts the previous hour value (269.99)
# Solution did not converge at index 2019-11-08 11:00:00: assigning to Ts the previous hour value (265.47)
# Solution did not converge at index 2019-11-08 12:00:00: assigning to Ts the previous hour value (265.47)
# Solution did not converge at index 2019-11-08 23:00:00: assigning to Ts the previous hour value (267.26)
# Solution did not converge at index 2019-11-09 00:00:00: assigning to Ts the previous hour value (267.26)
# Solution did not converge at index 2019-11-09 15:00:00: assigning to Ts the previous hour value (267.9)
# Solution did not converge at index 2019-11-09 17:00:00: assigning to Ts the previous hour value (266.96)
# Solution did not converge at index 2019-11-21 09:00:00: assigning to Ts the previous hour value (271.32)
# 1nNumerical method of Ts - solution did not converge 216 times.
# Ts values filled with the respectively previous value in the time series.

# %%
Ts_values.plot()

input_data['Tair'].plot(label = 'Tair')
plt.legend()

# %% [markdown]
# ## Evaluate all the other output variables

# %%
output_data = pd.DataFrame(index=input_data.index)

output_data['Ts'] = Ts_values
output_data['RH_s'] = surface_relative_humidity(input_data['RH_air'], output_data['Ts'], 
                                                input_data['Tair'], input_data['prec'], 
                                                input_data['snow_cover'], input_data['u'])
output_data['q_s'] = specific_humidity(output_data['Ts'], output_data['RH_s'])
output_data['q_air'] = specific_humidity(output_data['Ts'], input_data['RH_air'])
output_data['LWout'] = longwave_out(output_data['Ts'])
output_data['SH'] = sensible_heat_flux(input_data['u'], output_data['Ts'], input_data['Tair'])
output_data['LE'] = latent_heat_flux(input_data['u'], output_data['q_s'], output_data['q_air'])
output_data
# Out:
#                             Ts      RH_s       q_s     q_air       LWout  \
# time
# 2019-01-01 00:00:00  261.94138  0.839388 -1.743023 -1.745538  258.923362
# 2019-01-01 01:00:00  262.01923  0.833513 -1.743615 -1.746165  259.231312
# 2019-01-01 02:00:00  262.19520  0.810702 -1.746229 -1.748926  259.928404
# 2019-01-01 03:00:00  262.56476  0.774004 -1.750616 -1.753576  261.396965
# 2019-01-01 04:00:00  262.64880  0.722155 -1.758512 -1.761945  261.731791
# ...                        ...       ...       ...       ...         ...
# 2019-12-31 19:00:00  262.52180  0.778796 -1.750009 -1.752931  261.225932
# 2019-12-31 20:00:00  262.46268  0.804598 -1.746558 -1.749286  260.990698
# 2019-12-31 21:00:00  262.93790  0.821260 -1.743554 -1.746141  262.886057
# 2019-12-31 22:00:00  262.75607  0.830064 -1.742766 -1.745303  262.159635
# 2019-12-31 23:00:00  263.01923  0.813188 -1.744443 -1.747081  263.211464
#
#                              SH          LE
# time
# 2019-01-01 00:00:00  -99.993868   93.843615
# 2019-01-01 01:00:00 -123.938216  117.907627
# 2019-01-01 02:00:00 -145.994522  146.940164
# 2019-01-01 03:00:00 -162.993846  180.005235
# 2019-01-01 04:00:00 -182.110817  233.297571
# ...                         ...         ...
# 2019-12-31 19:00:00  -82.919992   90.432141
# 2019-12-31 20:00:00  -63.679497   64.812126
# 2019-12-31 21:00:00  -89.230902   86.130986
# 2019-12-31 22:00:00  -89.546813   84.768644
# 2019-12-31 23:00:00  -77.760949   76.552143
#
# [8760 rows x 7 columns]

# %%
#Path to allocate data
folder_path = "../data/synthetic_dataset/"

# List of variables with a time dimension
variables = [var for var in output_data.columns]

# Save each variable as a separate CSV file
for var in variables:
    # Convert to a DataFrame for easier CSV export
    df = output_data[var].to_frame()
    # Drop NaN values (if any) to keep the CSV clean
    #df = df.dropna()
    # Save to CSV
    df.to_csv(folder_path+f"{var}.csv")


print("Data successfully saved as individual CSV files in data/synthetic_dataset.")
# Out:
# Data successfully saved as individual CSV files in data/synthetic_dataset.

# %% [markdown]
# ## Appendix: why it makes sense that Ts has a bigger amplitude than Tair
# credits: Perplexity.ai

# %% [markdown]
# it actually does make sense for the surface temperature to have a larger amplitude than air temperature in a time series. Here's why:
# Thermal properties: The Earth's surface (soil, rock, vegetation, etc.) has different thermal properties compared to air. It typically has a lower specific heat capacity, meaning it can heat up and cool down more quickly than air.
# Direct solar radiation: The surface directly absorbs solar radiation during the day, causing it to heat up more rapidly and to higher temperatures than the air above it. At night, the surface radiates heat more efficiently than air, allowing it to cool more quickly.
# Atmospheric buffering: The air temperature is buffered by various factors such as wind, humidity, and atmospheric mixing, which tend to moderate temperature extremes. The surface doesn't benefit from these buffering effects to the same extent.
# Diurnal cycle: During a typical day-night cycle, the surface temperature often shows a more pronounced variation:
# During the day, especially under clear sky conditions, the surface can become much warmer than the air above it.
# At night, especially under clear, calm conditions, the surface can cool more rapidly than the air through radiative cooling.
# Urban heat island effect: In urban areas, surfaces like asphalt and concrete can reach much higher temperatures during the day and cool more at night compared to air temperatures.
# Microclimates: Surface temperatures can vary significantly over short distances due to factors like shading, moisture content, and surface type, leading to larger local temperature amplitudes.
# Seasonal effects: On a seasonal scale, surfaces exposed to direct sunlight can show larger temperature swings than air temperatures, especially in areas with high solar radiation and low atmospheric moisture.
# Measurement considerations: Surface temperature is often measured by infrared thermometers or satellite sensors, which capture the skin temperature of the surface. This can show more extreme values than air temperature measured at standard heights (usually 1.5-2 meters above the ground).
# Given these factors, it is quite common and expected for surface temperature to show larger amplitudes than air temperature in many environments. This larger amplitude in surface temperature is an important factor in many environmental and ecological processes, including energy balance, evapotranspiration, and ecosystem dynamics.
